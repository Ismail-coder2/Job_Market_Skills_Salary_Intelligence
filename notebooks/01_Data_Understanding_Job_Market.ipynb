# %% [markdown]
# # Job Market Skills & Salary Intelligence Platform
#
# ## 01 — Data Understanding & Exploration
#
# **Objective:** Analyze technology job-market data to identify in-demand skills, salary patterns, job roles, experience requirements, and location trends.
